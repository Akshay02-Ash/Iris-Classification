# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import tensorflow as tf
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Load iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# One-hot encode the target labels
encoder = OneHotEncoder(sparse=False)
y_onehot = encoder.fit_transform(y.reshape(-1, 1))

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot, test_size=0.2, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')  # 3 output classes
])

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=8, verbose=1)

# Evaluate model
loss, accuracy = model.evaluate(X_test_scaled, y_test, verbose=0)
print(f'Test Accuracy: {accuracy}')

# Predictions
predictions = model.predict(X_test_scaled)
predicted_labels = np.argmax(predictions, axis=1)
print(predicted_labels)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Epoch 1/50
# 15/15 [==============================] - 1s 3ms/step - loss: 0.8037 - accuracy: 0.6167
# Epoch 2/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.7471 - accuracy: 0.6667
# Epoch 3/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6981 - accuracy: 0.7000
# Epoch 4/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.6526 - accuracy: 0.7167
# Epoch 5/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.6116 - accuracy: 0.7250
# Epoch 6/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5749 - accuracy: 0.7583
# Epoch 7/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5424 - accuracy: 0.7917
# Epoch 8/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.5111 - accuracy: 0.8083
# Epoch 9/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.4842 - accuracy: 0.8167
# Epoch 10/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.4583 - accuracy: 0.8333
# Epoch 11/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4332 - accuracy: 0.8583
# Epoch 12/50
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4114 - accuracy: 0.8667
# Epoch 13/50
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3883 - accuracy: 0.8833
# Epoch 14/50
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3692 - accuracy: 0.8917
# Epoch 15/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3529 - accuracy: 0.9000
# Epoch 16/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3363 - accuracy: 0.9167
# Epoch 17/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3207 - accuracy: 0.9167
# Epoch 18/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.3067 - accuracy: 0.9167
# Epoch 19/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2946 - accuracy: 0.9167
# Epoch 20/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2814 - accuracy: 0.9167
# Epoch 21/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2710 - accuracy: 0.9250
# Epoch 22/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2577 - accuracy: 0.9417
# Epoch 23/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2472 - accuracy: 0.9333
# Epoch 24/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2346 - accuracy: 0.9417
# Epoch 25/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2250 - accuracy: 0.9583
# Epoch 26/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 0.9500
# Epoch 27/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2045 - accuracy: 0.9500
# Epoch 28/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1965 - accuracy: 0.9583
# Epoch 29/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1895 - accuracy: 0.9583
# Epoch 30/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1812 - accuracy: 0.9500
# Epoch 31/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1744 - accuracy: 0.9583
# Epoch 32/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1678 - accuracy: 0.9583
# Epoch 33/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1619 - accuracy: 0.9583
# Epoch 34/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.1578 - accuracy: 0.9500
# Epoch 35/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9583
# Epoch 36/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9667
# Epoch 37/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1405 - accuracy: 0.9667
# Epoch 38/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1361 - accuracy: 0.9667
# Epoch 39/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9583
# Epoch 40/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1282 - accuracy: 0.9667
# Epoch 41/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9750
# Epoch 42/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1202 - accuracy: 0.9667
# Epoch 43/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1168 - accuracy: 0.9667
# Epoch 44/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9750
# Epoch 45/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1125 - accuracy: 0.9667
# Epoch 46/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1093 - accuracy: 0.9667
# Epoch 47/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1061 - accuracy: 0.9750
# Epoch 48/50
# 15/15 [==============================] - 0s 4ms/step - loss: 0.1045 - accuracy: 0.9667
# Epoch 49/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1016 - accuracy: 0.9667
# Epoch 50/50
# 15/15 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9583
# Test Accuracy: 1.0
# 1/1 [==============================] - 0s 54ms/step
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
import pickle

# Save the model to Google Drive
with open('/content/drive/MyDrive/iris_model.pkl', 'wb') as f:
  pickle.dump(model, f)
